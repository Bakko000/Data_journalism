# %% [markdown]
# ## 1 parte

# %%
'recensioncritica_all_ovest_niente_di_nuovo.pickle',
    'recensionicritica_giorni_perduti.pickle',
    'recensionicritica_fronte_del_porto.pickle',
    'recensionicritica_lappartamento.pickle',
    'recensionicritica_lawrencedarabia.pickle'

# %%
def analyze_sentiment(lista):
    blob = TextBlob(lista)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
            return 'Positive'
    elif sentiment < 0:
            return 'Negative'
    else:
            return 'Neutral'

with open('recensioni_a_ovest_niente_nuovo.pickle', 'rb') as file:
    lista = pickle.load(file)
    print(len(lista))
    


sentiments = []
for i in lista:
    for d in i:
        sentiment = analyze_sentiment(d)
        sentiments.append(sentiment)

print(len(sentiments))
# Out:
# 185
# 185

# %%
import os

path = 'sentiment_finale/oscar/critica/'

if os.path.exists(path):
    print(f"Il percorso '{path}' esiste.")
else:
    print(f"Il percorso '{path}' non esiste.")
# Out:
# Il percorso 'sentiment_finale/oscar/critica/' esiste.

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)

# Example usage
pickle_csv_mapping = {
    'recensioncritica_all_ovest_niente_di_nuovo.pickle': ('sentiment_finale/oscar/critica/a_ovest_niente_di_nuovo_r_critica.csv', 'A Ovest Niente di Nuovo'),
    'recensionicritica_giorni_perduti.pickle': ('sentiment_finale/oscar/critica/giorni_perduti_r_critica.csv', 'Giorni Perduti'),
   'recensionicritica_fronte_del_porto.pickle': ('sentiment_finale/oscar/critica/fronte_del_porto_r_crtica.csv', 'Fronte del Porto'),
    'recensionicritica_lappartamento.pickle': ('sentiment_finale/oscar/critica/appartamento_r_critica.csv', "L'appartamento"),
        'recensionicritica_lawrencedarabia.pickle': ('sentiment_finale/oscar/critica/lawrence_arabia_r_critica.csv', "Lawrence di Arabia")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/critica/a_ovest_niente_di_nuovo_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/giorni_perduti_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/fronte_del_porto_r_crtica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/appartamento_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/lawrence_arabia_r_critica.csv' creato con successo.

# %% [markdown]
# ## 2 parte

# %%
'recensioncritica_quinto_potere.pickle',
    'recensionicritica_gandhi.pickle',
    'recensionicritica_la_mia_africa.pickle',
    'recensionicritica_lultimo_imperatore.pickle',
    'recensionicritica_rain_man.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)

    
# Example usage
pickle_csv_mapping = {
    'recensioncritica_quinto_potere.pickle': ('sentiment_finale/oscar/critica/quinto_potere_r_critica.csv', 'Quinto Potere'),
    'recensioni_gandhi.pickle': ('sentiment_finale/oscar/critica/gandhi_r_critica.csv', 'Gandhi'),
     'recensionicritica_la_mia_africa.pickle': ('sentiment_finale/oscar/critica/la_mia_africa_r_critica.csv', 'La mia Africa'),
     'recensionicritica_lultimo_imperatore.pickle': ('sentiment_finale/oscar/critica/ultimo_imperatore_r_critica.csv', "L'ultimo imperatore"),
    'recensionicritica_rain_man.pickle': ('sentiment_finale/oscar/critica/rain_man_r_critica.csv', "Rain Man")
    # A
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/critica/quinto_potere_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/gandhi_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/la_mia_africa_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/ultimo_imperatore_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/rain_man_r_critica.csv' creato con successo.

# %% [markdown]
# ## 3 parte

# %%
'recensioncritica_a_spasso_con_daisy.pickle',
    'recensionicritica_schindler_list.pickle',
    'recensionicritica_forrest_gump.pickle',
    'recensionicritica_il_paziente__inglese.pickle',
    'recensionicritica_crash.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


pickle_csv_mapping = {
    'recensioncritica_a_spasso_con_daisy.pickle': ('sentiment_finale/oscar/critica/a_spasso_con_daisy_r_critica.csv', 'A spasso con Daisy'),
     'recensionicritica_schindler_list.pickle': ('sentiment_finale/oscar/critica/schindler_list_r_critica.csv', "Schindler's List"),
    'recensionicritica_forrest_gump.pickle': ('sentiment_finale/oscar/critica/forrest_gump_r_critica.csv', 'Forrest Gump'),
     'recensionicritica_il_paziente__inglese.pickle': ('sentiment_finale/oscar/critica/il_paziente_inglese_r_critica.csv', "Il paziente inglese"),
    'recensionicritica_crash.pickle':('sentiment_finale/oscar/critica/crash_r_critica.csv', "Crash")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/critica/a_spasso_con_daisy_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/schindler_list_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/forrest_gump_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/il_paziente_inglese_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/crash_r_critica.csv' creato con successo.

# %% [markdown]
# ## 4 parte

# %%
'recensioncritica_the_millionaire.pickle',
    'recensionicritica_il_discorso_del_re.pickle',
    'recensionicritica_12_anni_schiavo.pickle',
    'recensionicritica_il_caso_spotlight.pickle',
    'recensionicritica_moonlight.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


# Example usage
pickle_csv_mapping = {
    'recensioncritica_the_millionaire.pickle': ('sentiment_finale/oscar/critica/the_millionaire_r_critica.csv', "The Millionaire"),
    'recensionicritica_il_discorso_del_re.pickle': ('sentiment_finale/oscar/critica/il_discorso_del_re_r_critica.csv', 'Il discorso del re'),
     'recensionicritica_12_anni_schiavo.pickle': ('sentiment_finale/oscar/critica/12_anni_schiavo_r_critica.csv', '12 anni schiavo'),
   'recensionicritica_il_caso_spotlight.pickle': ('sentiment_finale/oscar/critica/il_caso_spotlight_r_critica.csv', "Il caso spotlight"),
   'recensionicritica_moonlight.pickle': ('sentiment_finale/oscar/critica/moonlight_r_critica.csv', "Moonlight")
    
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/critica/the_millionaire_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/il_discorso_del_re_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/12_anni_schiavo_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/il_caso_spotlight_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/moonlight_r_critica.csv' creato con successo.

# %% [markdown]
# ## 5 parte

# %%
'recensioncritica_la_forma_dellacqua.pickle',
    'recensionicritica_green_book.pickle',
    'recensionicritica_parasite.pickle',
    'recensionicritica_nomadland.pickle',
    'recensionicritica_CODA.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


# Example usage
pickle_csv_mapping = {
   'recensioncritica_la_forma_dellacqua.pickle': ('sentiment_finale/oscar/critica/la_forma_dellacqua_r_critica.csv', "La forma dell'acqua"),
     'recensionicritica_green_book.pickle': ('sentiment_finale/oscar/critica/green_book_r_critica.csv', "Green book"),
       'recensionicritica_parasite.pickle': ('sentiment_finale/oscar/critica/psarasite_r_critica.csv', 'Parasite'),
     'recensionicritica_nomadland.pickle': ('sentiment_finale/oscar/critica/nomadland_r_critica.csv', "Nomadland"),
    'recensionicritica_CODA.pickle': ('sentiment_finale/oscar/critica/cosa_r_critica.csv', "CODA"),
   
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/critica/la_forma_dellacqua_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/green_book_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/psarasite_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/nomadland_r_critica.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/critica/cosa_r_critica.csv' creato con successo.
