# %% [markdown]
# ## 1 parte

# %%
'recensioni_a_ovest_niente_nuovo.pickle',
    'recensioni_giorni_perduti.pickle',
    'recensioni_fronte_del_porto.pickle',
    'recensioni_appuntamneto.pickle'

# %%
def analyze_sentiment(lista):
    blob = TextBlob(lista)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
            return 'Positive'
    elif sentiment < 0:
            return 'Negative'
    else:
            return 'Neutral'

with open('recensioni_a_ovest_niente_nuovo.pickle', 'rb') as file:
    lista = pickle.load(file)
    print(len(lista))
    


sentiments = []
for i in lista:
    for d in i:
        sentiment = analyze_sentiment(d)
        sentiments.append(sentiment)

print(len(sentiments))
# Out:
# 185
# 185

# %%
import os

path = 'sentiment_finale/oscar/utenti/'

if os.path.exists(path):
    print(f"Il percorso '{path}' esiste.")
else:
    print(f"Il percorso '{path}' non esiste.")
# Out:
# Il percorso 'sentiment_finale/oscar/utenti/' esiste.

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    sentiments = []
    for i in lista:
        for d in i:
            sentiment = analyze_sentiment(d)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename):
   
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Sentiment'])  # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
   
    for pickle_file, csv_filename in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename)

            

# Example usage
pickle_csv_mapping = {
    'recensioni_a_ovest_niente_nuovo.pickle': 'sentiment_finale/oscar/utenti/a_ovest_niente_di_nuovo_r_utenti.csv',
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/a_ovest_niente_di_nuovo_r_utenti.csv' creato con successo.

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)

# Example usage
pickle_csv_mapping = {
    'recensioni_a_ovest_niente_nuovo.pickle': ('sentiment_finale/oscar/utenti/a_ovest_niente_di_nuovo_r_utenti.csv', 'A Ovest Niente di Nuovo'),
    'recensioni_giorni_perduti.pickle': ('sentiment_finale/oscar/utenti/giorni_perduti_r_utenti.csv', 'Giorni Perduti'),
    'recensioni_fronte_del_porto.pickle': ('sentiment_finale/oscar/utenti/fronte_del_porto_r_utenti.csv', 'Fronte del Porto'),
    'recensioni_appuntamneto.pickle': ('sentiment_finale/oscar/utenti/appartamento_r_utenti.csv', "L'appartamento")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/a_ovest_niente_di_nuovo_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/giorni_perduti_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/fronte_del_porto_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/appartamento_r_utenti.csv' creato con successo.

# %% [markdown]
# ## 2 parte

# %%
'recensioni_quinto_potere.pickle',
    'recensioni_gandhi.pickle',
    'recensioni_a_spassp_con_daisy.pickle',
    'recensioni_schinderl_list.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)

# Example usage
pickle_csv_mapping = {
    'recensioni_quinto_potere.pickle': ('sentiment_finale/oscar/utenti/quinto_potere_r_utenti.csv', 'Quinto Potere'),
    'recensioni_gandhi.pickle': ('sentiment_finale/oscar/utenti/gandhi_r_utenti.csv', 'Gandhi'),
     'recensioni_a_spassp_con_daisy.pickle': ('sentiment_finale/oscar/utenti/a_spasso_con_daisy_r_utenti.csv', 'A spasso con Daisy'),
     'recensioni_schinderl_list.pickle': ('sentiment_finale/oscar/utenti/schindler_list_r_utenti.csv', "Schindler's List")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/quinto_potere_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/gandhi_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/a_spasso_con_daisy_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/schindler_list_r_utenti.csv' creato con successo.

# %% [markdown]
# ## 3 parte

# %%
'recensioni_forest_gump.pickle',
    'recensioni_the_millionarie.pickle',
    'recensioni_12_anni_schiavo.pickle',
    'recensioni_il_caso_spotlight.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)

    
# Example usage
pickle_csv_mapping = {
    'recensioni_forest_gump.pickle': ('sentiment_finale/oscar/utenti/forrest_gump_r_utenti.csv', 'Forrest Gump'),
    'recensioni_the_millionarie.pickle': ('sentiment_finale/oscar/utenti/the_millionarie_r_utenti.csv', 'The Millionaire'),
    'recensioni_12_anni_schiavo.pickle': ('sentiment_finale/oscar/utenti/12_anni_schiavo_r_utenti.csv', '12 anni schiavo'),
     'recensioni_il_caso_spotlight.pickle': ('sentiment_finale/oscar/utenti/il_caso_spotlight_r_utenti.csv', "il caso spotlight")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/forrest_gump_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/the_millionarie_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/12_anni_schiavo_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/il_caso_spotlight_r_utenti.csv' creato con successo.

# %% [markdown]
# ## 4 parte

# %%
'recensioni_la_forma_dell_acqua.pickle',
    'recensioni_green_book.pickle',
    'recensioni_nomadlans.pickle',
    'recensioni_coda.pickle'

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


# Example usage
pickle_csv_mapping = {
    'recensioni_la_forma_dell_acqua.pickle': ('sentiment_finale/oscar/utenti/la_forma_dell_acqua_r_utenti.csv', "La forma dell'acqua"),
    'recensioni_green_book.pickle': ('sentiment_finale/oscar/utenti/green_book_r_utenti.csv', 'Green book'),
     'recensioni_nomadlans.pickle': ('sentiment_finale/oscar/utenti/nomadland_r_utenti.csv', 'Nomadland'),
    'recensioni_coda.pickle': ('sentiment_finale/oscar/utenti/coda_r_utenti.csv', "Coda")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/la_forma_dell_acqua_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/green_book_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/nomadland_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/coda_r_utenti.csv' creato con successo.

# %% [markdown]
# ## 5 parte

# %%
"La_mia_africa.pickle",
    "Lawrence_Arabia.pickle",
    "Ultimo_imperatore.pickle",
    "Rain_man.pickle",
    "Il_paziente_inglese.pickle",
    "Crash.pickle",
    "Discorso_del_re.pickle",
    "Moonlight.pickle"

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


# Example usage
pickle_csv_mapping = {
    "La_mia_africa.pickle": ('sentiment_finale/oscar/utenti/la_mia_africa_r_utenti.csv', 'La mia Africa'),
     "Lawrence_Arabia.pickle": ('sentiment_finale/oscar/utenti/lawrence_arabia_utenti.csv', "Lawrence d'Arabia"),
      "Il_paziente_inglese.pickle": ('sentiment_finale/oscar/utenti/Il_paziente_inglese_r_utenti.csv', 'Il paziente inglese'),
     "Crash.pickle": ('sentiment_finale/oscar/utenti/Crash_r_utenti.csv', "Crash"),
    "Discorso_del_re.pickle": ('sentiment_finale/oscar/utenti/Discorso_del_re_r_utenti.csv', "Il discorso del re"),
    "Moonlight.pickle": ('sentiment_finale/oscar/utenti/Moonligh_r_utenti.csv', "Moonlight"),
    "Ultimo_imperatore.pickle": ('sentiment_finale/oscar/utenti/ultimo_imperatore_r_utenti.csv', "L'ultimo imperatore"),
    "Rain_man.pickle": ('sentiment_finale/oscar/utenti/rain_man_r_utenti.csv', "Rain man")
    # Add more mappings as needed
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/la_mia_africa_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/lawrence_arabia_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/Il_paziente_inglese_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/Crash_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/Discorso_del_re_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/Moonligh_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/ultimo_imperatore_r_utenti.csv' creato con successo.
# File CSV 'sentiment_finale/oscar/utenti/rain_man_r_utenti.csv' creato con successo.

# %% [markdown]
# ## 6 parte

# %%
import pickle
import csv
from textblob import TextBlob
import os

def analyze_sentiment(frasi):
    """
    Analyzes the sentiment of a given sentence.
    
    :param frasi: str, the input sentence
    :return: str, sentiment of the sentence ('Positive', 'Negative', 'Neutral')
    """
    blob = TextBlob(frasi)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        return 'Positive'
    elif sentiment < 0:
        return 'Negative'
    else:
        return 'Neutral'

def process_sentiments_from_pickle(pickle_file):
    """
    Processes a single pickle file, analyzes sentiments, and returns a list of sentiments.
    
    :param pickle_file: str, path to a pickle file
    :return: list of str, sentiment results
    """
    sentiments = []
    
    if not os.path.isfile(pickle_file):
        print(f"File not found: {pickle_file}")
        return sentiments
    
    with open(pickle_file, 'rb') as file:
        lista = pickle.load(file)
    
    for sublista in lista:
        for frase in sublista:
            sentiment = analyze_sentiment(frase)
            sentiments.append(sentiment)
    
    return sentiments

def save_sentiments_to_csv(sentiments, csv_filename, movie_title):
    """
    Saves the sentiment results to a CSV file with a single column 'Sentiment'.
    
    :param sentiments: list of str, sentiment results
    :param csv_filename: str, path to the output CSV file
    :param movie_title: str, title of the movie to include as the first row
    """
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow([movie_title])  # Write movie title
        writer.writerow(['Sentiment'])   # Write header
        for sentiment in sentiments:
            writer.writerow([sentiment])
    
    print(f"File CSV '{csv_filename}' creato con successo.")

def process_pickles_with_custom_csv(pickle_csv_mapping):
    """
    Processes each pickle file and saves results to specified CSV files.
    
    :param pickle_csv_mapping: dict, mapping of pickle file paths to (CSV file paths, movie titles)
    """
    for pickle_file, (csv_filename, movie_title) in pickle_csv_mapping.items():
        sentiments = process_sentiments_from_pickle(pickle_file)
        if sentiments:  # Only save if there are sentiments to write
            save_sentiments_to_csv(sentiments, csv_filename, movie_title)


# Example usage
pickle_csv_mapping = {
    "recensioni_parasite.pickle": ('sentiment_finale/oscar/utenti/parasite_r_utenti.csv', 'Parasite'),
     
}

# Process each pickle file and save results to specified CSV files
process_pickles_with_custom_csv(pickle_csv_mapping)
# Out:
# File CSV 'sentiment_finale/oscar/utenti/parasite_r_utenti.csv' creato con successo.
