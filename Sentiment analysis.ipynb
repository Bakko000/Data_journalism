# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import pandas as pdp
import requests
import random

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

url = "https://www.imdb.com/title/tt6751668/reviews"

page = requests.get(url, headers = headers)

# %%
page
# Out:
# <Response [200]>

# %%
soup = soup(page.text, "html.parser")

# %%
page.status_code
# Out:
# 200

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# ...

# %%
from bs4 import BeautifulSoup
recensioni=[]
if page.status_code == 200:
    # Utilizza un altro nome per l'oggetto BeautifulSoup
    soup_1 =  BeautifulSoup(page.text, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup_1.find_all('div', class_='text show-more__control')

    # Estrai e stampa i contenuti dei <div>
    for div in divs:
        print('una')
        print(div.get_text(strip=True))
        recensioni.append([div.get_text(strip=True)])
        
        
else:
    print(f"Errore nella richiesta: {page.status_code}")
# Out:
# una
# ...

# %%
len(recensioni)
# Out:
# 24

# %%
recensioni
# Out:
# [['It\'s not really a review but my attempt to explain how I interpreted the movie to those who complain that the film is overrated, especially if the reason is that they didn\'t like the second half of it.It\'s much easier to understand the message of a movie when the \'good guys\' win or the \'bad guys\' get punished in the end. I\'m not saying that all Hollywood films are so naive in their portrayal of moral values. But still, I believe that Parasite is much more subtle than most other movies that people are accustomed to watching in which there\'s a character with a clearer \'moral center\' whom audiences can easily relate to. So, I think it\'s no surprise if the message of this film had failed to register for some of the audiences.Some complained that they don\'t understand Ki-Taek\'s motive for killing Mr. Park. But to fully appreciate this, you need to understand the meaning of a recurring expression in the dialogue which is, "crossing the line".It\'s a deliberately ambiguous 
# ...

# %%
import selenium
driver=selenium.webdriver.Chrome()

# %%
#from selenium import webdriver
from selenium.webdriver.common.by import By
#import time

# Specifica il percorso del ChromeDriver
driver_path = 'chromedriver-mac-arm64/chromedriver'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

# Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
driver_path = 'chromedriver-mac-arm64/chromedriver'
service = ChromeService(executable_path=driver_path)

# Opzioni per il WebDriver (facoltativo)
chrome_options = Options()
# chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
# chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

driver = webdriver.Chrome(service=service, options=chrome_options)

# Apri la pagina web
url = 'https://www.imdb.com/title/tt6751668/reviews'
driver.get(url)

# Attendi che la pagina si carichi
time.sleep(3)

# Loop per cliccare su 'Load More' e caricare ulteriori recensioni
while True:
    try:
        # Trova il pulsante 'Load More'
        load_more_button = driver.find_element(By.ID, 'load-more-trigger')
        
        # Clicca sul pulsante
        load_more_button.click()
        
        # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
        time.sleep(2)
    except:
        # Se il pulsante non è più trovato, esci dal loop
        break

# Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
content = driver.page_source

# Usa BeautifulSoup per analizzare il contenuto HTML
soup = BeautifulSoup(content, 'html.parser')

# Trova tutti i <div> con la classe "text show-more__control"
divs = soup.find_all('div', class_='text show-more__control')

# Estrai e stampa i contenuti dei <div>
recensioni = []
for div in divs:
    recensione = div.get_text(strip=True)
    print(recensione)
    recensioni.append([recensione])

# Chiudi il driver
driver.quit()

# Ora puoi usare la lista 'recensioni' come preferisci
# Out:
# It's not really a review but my attempt to explain how I interpreted the movie to those who complain that the film is overrated, especially if the reason is that they didn't like the second half of it.It's much easier to understand the message of a movie when the 'good guys' win or the 'bad guys' get punished in the end. I'm not saying that all Hollywood films are so naive in their portrayal of moral values. But still, I believe that Parasite is much more subtle than most other movies that people are accustomed to watching in which there's a character with a clearer 'moral center' whom audiences can easily relate to. So, I think it's no surprise if the message of this film had failed to register for some of the audiences.Some complained that they don't understand Ki-Taek's motive for killing Mr. Park. But to fully appreciate this, you need to understand the meaning of a recurring expression in the dialogue which is, "crossing the line".It's a deliberately ambiguous phrase that can ei
# ...

# %%
len(recensioni)
# Out:
# 3118

# %%
recensioni
# Out:
# [['It\'s not really a review but my attempt to explain how I interpreted the movie to those who complain that the film is overrated, especially if the reason is that they didn\'t like the second half of it.It\'s much easier to understand the message of a movie when the \'good guys\' win or the \'bad guys\' get punished in the end. I\'m not saying that all Hollywood films are so naive in their portrayal of moral values. But still, I believe that Parasite is much more subtle than most other movies that people are accustomed to watching in which there\'s a character with a clearer \'moral center\' whom audiences can easily relate to. So, I think it\'s no surprise if the message of this film had failed to register for some of the audiences.Some complained that they don\'t understand Ki-Taek\'s motive for killing Mr. Park. But to fully appreciate this, you need to understand the meaning of a recurring expression in the dialogue which is, "crossing the line".It\'s a deliberately ambiguous 
# ...

# %%
import pickle
with open('recensioni_parasite.pickle', 'wb') as f:
    pickle.dump(recensioni, f)

# %% [markdown]
# ## iterazioni

# %%
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

def scrape_reviews(url):
    # Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
    driver_path = 'chromedriver-mac-arm64/chromedriver'
    service = ChromeService(executable_path=driver_path)

    # Opzioni per il WebDriver (facoltativo)
    chrome_options = Options()
    # chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
    # chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

    driver = webdriver.Chrome(service=service, options=chrome_options)

    # Apri la pagina web
    driver.get(url)

    # Attendi che la pagina si carichi
    time.sleep(3)#3

    # Loop per cliccare su 'Load More' e caricare ulteriori recensioni
    while True:
        try:
            # Trova il pulsante 'Load More'
            load_more_button = driver.find_element(By.ID, 'load-more-trigger')
            
            # Clicca sul pulsante
            load_more_button.click()
            
            # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
            time.sleep(5)#
        except:
            # Se il pulsante non è più trovato, esci dal loop
            break

    # Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
    content = driver.page_source

    # Usa BeautifulSoup per analizzare il contenuto HTML
    soup = BeautifulSoup(content, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup.find_all('div', class_='text show-more__control')

    # Estrai e raccogli i contenuti dei <div>
    recensioni = []
    for div in divs:
        recensione = div.get_text(strip=True)
        recensioni.append([recensione])

    # Chiudi il driver
    driver.quit()

    return recensioni

# Lista di URL da cui raccogliere le recensioni
urls = [
    'https://www.imdb.com/title/tt0020629/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0037884/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0047296/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0053604/reviews/?ref_=tt_ov_rt'
]

# Lista di nomi di file corrispondenti agli URL
file_names = [
    'recensioni_a_ovest_niente_nuovo.pickle',
    'recensioni_giorni_perduti.pickle',
    'recensioni_fronte_del_porto.pickle',
    'recensioni_appuntamneto.pickle'
    
    # aggiungi altri nomi di file qui
]

# Verifica che il numero di URL corrisponda al numero di nomi di file
if len(urls) != len(file_names):
    raise ValueError("Il numero di URL deve corrispondere al numero di nomi di file.")

# Itera su ciascun URL e nome di file e salva le recensioni in file pickle
for url, file_name in zip(urls, file_names):
    recensioni = scrape_reviews(url)
    
    with open(file_name, 'wb') as file:
        pickle.dump(recensioni, file)
    print(f"Recensioni salvate in {file_name}", len(recensioni))
# Out:
# Recensioni salvate in recensioni_a_ovest_niente_nuovo.pickle 185
# Recensioni salvate in recensioni_giorni_perduti.pickle 118
# Recensioni salvate in recensioni_fronte_del_porto.pickle 237
# Recensioni salvate in recensioni_appuntamneto.pickle 272

# %% [markdown]
# ## 2 parte

# %%
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

def scrape_reviews(url):
    # Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
    driver_path = 'chromedriver-mac-arm64/chromedriver'
    service = ChromeService(executable_path=driver_path)

    # Opzioni per il WebDriver (facoltativo)
    chrome_options = Options()
    # chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
    # chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

    driver = webdriver.Chrome(service=service, options=chrome_options)

    # Apri la pagina web
    driver.get(url)

    # Attendi che la pagina si carichi
    time.sleep(5)

    # Loop per cliccare su 'Load More' e caricare ulteriori recensioni
    while True:
        try:
            # Trova il pulsante 'Load More'
            load_more_button = driver.find_element(By.ID, 'load-more-trigger')
            
            # Clicca sul pulsante
            load_more_button.click()
            
            # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
            time.sleep(5)
        except:
            # Se il pulsante non è più trovato, esci dal loop
            break

    # Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
    content = driver.page_source

    # Usa BeautifulSoup per analizzare il contenuto HTML
    soup = BeautifulSoup(content, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup.find_all('div', class_='text show-more__control')

    # Estrai e raccogli i contenuti dei <div>
    recensioni = []
    for div in divs:
        recensione = div.get_text(strip=True)
        recensioni.append([recensione])

    # Chiudi il driver
    driver.quit()

    return recensioni

# Lista di URL da cui raccogliere le recensioni
urls = [
    
    'https://www.imdb.com/title/tt0074958/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0083987/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0097239/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt0108052/reviews/?ref_=tt_ov_rt'
    
   
    
    # aggiungi altri URL qui
]

# Lista di nomi di file corrispondenti agli URL
file_names = [
    
    'recensioni_quinto_potere.pickle',
    'recensioni_gandhi.pickle',
    'recensioni_a_spassp_con_daisy.pickle',
    'recensioni_schinderl_list.pickle'
    
    # aggiungi altri nomi di file qui
]

# Verifica che il numero di URL corrisponda al numero di nomi di file
if len(urls) != len(file_names):
    raise ValueError("Il numero di URL deve corrispondere al numero di nomi di file.")

# Itera su ciascun URL e nome di file e salva le recensioni in file pickle
for url, file_name in zip(urls, file_names):
    recensioni = scrape_reviews(url)
    
    with open(file_name, 'wb') as file:
        pickle.dump(recensioni, file)
    print(f"Recensioni salvate in {file_name}", len(recensioni))
# Out:
# Recensioni salvate in recensioni_quinto_potere.pickle 240
# Recensioni salvate in recensioni_gandhi.pickle 197
# Recensioni salvate in recensioni_a_spassp_con_daisy.pickle 132
# Recensioni salvate in recensioni_schinderl_list.pickle 1728

# %% [markdown]
# ## 3 parte

# %%
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

def scrape_reviews(url):
    # Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
    driver_path = 'chromedriver-mac-arm64/chromedriver'
    service = ChromeService(executable_path=driver_path)

    # Opzioni per il WebDriver (facoltativo)
    chrome_options = Options()
    # chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
    # chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

    driver = webdriver.Chrome(service=service, options=chrome_options)

    # Apri la pagina web
    driver.get(url)

    # Attendi che la pagina si carichi
    time.sleep(5)

    # Loop per cliccare su 'Load More' e caricare ulteriori recensioni
    while True:
        try:
            # Trova il pulsante 'Load More'
            load_more_button = driver.find_element(By.ID, 'load-more-trigger')
            
            # Clicca sul pulsante
            load_more_button.click()
            
            # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
            time.sleep(5)
        except:
            # Se il pulsante non è più trovato, esci dal loop
            break

    # Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
    content = driver.page_source

    # Usa BeautifulSoup per analizzare il contenuto HTML
    soup = BeautifulSoup(content, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup.find_all('div', class_='text show-more__control')

    # Estrai e raccogli i contenuti dei <div>
    recensioni = []
    for div in divs:
        recensione = div.get_text(strip=True)
        recensioni.append([recensione])

    # Chiudi il driver
    driver.quit()

    return recensioni

# Lista di URL da cui raccogliere le recensioni
urls = [
    
    'https://www.imdb.com/title/tt0109830/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt1010048/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt2024544/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt1895587/reviews/?ref_=tt_ov_rt'
    
   
    
    # aggiungi altri URL qui
]

# Lista di nomi di file corrispondenti agli URL
file_names = [
    
    'recensioni_forest_gump.pickle',
    'recensioni_the_millionarie.pickle',
    'recensioni_12_anni_schiavo.pickle',
    'recensioni_il_caso_spotlight.pickle'
    
    # aggiungi altri nomi di file qui
]

# Verifica che il numero di URL corrisponda al numero di nomi di file
if len(urls) != len(file_names):
    raise ValueError("Il numero di URL deve corrispondere al numero di nomi di file.")

# Itera su ciascun URL e nome di file e salva le recensioni in file pickle
for url, file_name in zip(urls, file_names):
    recensioni = scrape_reviews(url)
    
    with open(file_name, 'wb') as file:
        pickle.dump(recensioni, file)
    print(f"Recensioni salvate in {file_name}", len(recensioni))
# Out:
# Recensioni salvate in recensioni_forest_gump.pickle 2599
# Recensioni salvate in recensioni_the_millionarie.pickle 778
# Recensioni salvate in recensioni_12_anni_schiavo.pickle 646
# Recensioni salvate in recensioni_il_caso_spotlight.pickle 420

# %% [markdown]
# ## 4 parte

# %%
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

def scrape_reviews(url):
    # Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
    driver_path = 'chromedriver-mac-arm64/chromedriver'
    service = ChromeService(executable_path=driver_path)

    # Opzioni per il WebDriver (facoltativo)
    chrome_options = Options()
    # chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
    # chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

    driver = webdriver.Chrome(service=service, options=chrome_options)

    # Apri la pagina web
    driver.get(url)

    # Attendi che la pagina si carichi
    time.sleep(3)

    # Loop per cliccare su 'Load More' e caricare ulteriori recensioni
    while True:
        try:
            # Trova il pulsante 'Load More'
            load_more_button = driver.find_element(By.ID, 'load-more-trigger')
            
            # Clicca sul pulsante
            load_more_button.click()
            
            # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
            time.sleep(5)
        except:
            # Se il pulsante non è più trovato, esci dal loop
            break

    # Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
    content = driver.page_source

    # Usa BeautifulSoup per analizzare il contenuto HTML
    soup = BeautifulSoup(content, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup.find_all('div', class_='text show-more__control')

    # Estrai e raccogli i contenuti dei <div>
    recensioni = []
    for div in divs:
        recensione = div.get_text(strip=True)
        recensioni.append([recensione])

    # Chiudi il driver
    driver.quit()

    return recensioni

# Lista di URL da cui raccogliere le recensioni
urls = [

    'https://www.imdb.com/title/tt5580390/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt6966692/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt9770150/reviews/?ref_=tt_ov_rt',
    'https://www.imdb.com/title/tt10366460/reviews/?ref_=tt_ov_rt'
    
    # aggiungi altri URL qui
]

# Lista di nomi di file corrispondenti agli URL
file_names = [
    'recensioni_la_forma_dell_acqua.pickle',
    'recensioni_green_book.pickle',
    'recensioni_nomadlans.pickle',
    'recensioni_coda.pickle'
    
    # aggiungi altri nomi di file qui
]

# Verifica che il numero di URL corrisponda al numero di nomi di file
if len(urls) != len(file_names):
    raise ValueError("Il numero di URL deve corrispondere al numero di nomi di file.")

# Itera su ciascun URL e nome di file e salva le recensioni in file pickle
for url, file_name in zip(urls, file_names):
    recensioni = scrape_reviews(url)
    
    with open(file_name, 'wb') as file:
        pickle.dump(recensioni, file)
    print(f"Recensioni salvate in {file_name}", len(recensioni))
# Out:
# Recensioni salvate in recensioni_la_forma_dell_acqua.pickle 1447
# Recensioni salvate in recensioni_green_book.pickle 1531
# Recensioni salvate in recensioni_nomadlans.pickle 901
# Recensioni salvate in recensioni_coda.pickle 574

# %% [markdown]
# ## 5 parte

# %%
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

def scrape_reviews(url):
    # Configura il WebDriver (assicurati di avere il chromedriver nella directory specificata o nel PATH)
    driver_path = 'chromedriver-mac-arm64/chromedriver'
    service = ChromeService(executable_path=driver_path)

    # Opzioni per il WebDriver (facoltativo)
    chrome_options = Options()
    # chrome_options.add_argument('--headless')  # Esegui il browser in modalità headless (facoltativo)
    # chrome_options.add_argument('--disable-gpu')  # Necessario per eseguire il browser in modalità headless in Windows (facoltativo)

    driver = webdriver.Chrome(service=service, options=chrome_options)

    # Apri la pagina web
    driver.get(url)

    # Attendi che la pagina si carichi
    time.sleep(3)

    # Loop per cliccare su 'Load More' e caricare ulteriori recensioni
    while True:
        try:
            # Trova il pulsante 'Load More'
            load_more_button = driver.find_element(By.ID, 'load-more-trigger')
            
            # Clicca sul pulsante
            load_more_button.click()
            
            # Attendi un po' di tempo per permettere il caricamento dei nuovi contenuti
            time.sleep(5)
        except:
            # Se il pulsante non è più trovato, esci dal loop
            break

    # Una volta che tutti i contenuti sono stati caricati, estrai il contenuto della pagina
    content = driver.page_source

    # Usa BeautifulSoup per analizzare il contenuto HTML
    soup = BeautifulSoup(content, 'html.parser')

    # Trova tutti i <div> con la classe "text show-more__control"
    divs = soup.find_all('div', class_='text show-more__control')

    # Estrai e raccogli i contenuti dei <div>
    recensioni = []
    for div in divs:
        recensione = div.get_text(strip=True)
        recensioni.append([recensione])

    # Chiudi il driver
    driver.quit()

    return recensioni

# Lista di URL da cui raccogliere le recensioni
urls = [
    "https://www.imdb.com/title/tt0089755/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt0056172/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt0093389/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt0095953/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt0116209/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt0375679/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt1504320/reviews/?ref_=tt_ov_rt",
    "https://www.imdb.com/title/tt4975722/reviews/?ref_=tt_ov_rt"

    
    
    # aggiungi altri URL qui
]

# Lista di nomi di file corrispondenti agli URL
file_names = [
    "La_mia_africa.pickle",
    "Lawrence_Arabia.pickle",
    "Ultimo_imperatore.pickle",
    "Rain_man.pickle",
    "Il_paziente_inglese.pickle",
    "Crash.pickle",
    "Discorso_del_re.pickle",
    "Moonlight.pickle"
]

# Verifica che il numero di URL corrisponda al numero di nomi di file
if len(urls) != len(file_names):
    raise ValueError("Il numero di URL deve corrispondere al numero di nomi di file.")

# Itera su ciascun URL e nome di file e salva le recensioni in file pickle
for url, file_name in zip(urls, file_names):
    recensioni = scrape_reviews(url)
    
    with open(file_name, 'wb') as file:
        pickle.dump(recensioni, file)
    print(f"Recensioni salvate in {file_name}", len(recensioni))
# Out:
# Recensioni salvate in La_mia_africa.pickle 189
# Recensioni salvate in Lawrence_Arabia.pickle 462
# Recensioni salvate in Ultimo_imperatore.pickle 137
# Recensioni salvate in Rain_man.pickle 364
# Recensioni salvate in Il_paziente_inglese.pickle 26
# Recensioni salvate in Crash.pickle 1057
# Recensioni salvate in Discorso_del_re.pickle 30
# Recensioni salvate in Moonlight.pickle 746
